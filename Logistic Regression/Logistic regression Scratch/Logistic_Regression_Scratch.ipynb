# %%
# !unzip helpers.zip
# Out:
# Archive:  helpers.zip
#    creating: helpers/
#    creating: helpers/dataset/
#   inflating: helpers/dataset/__init__.py
#    creating: helpers/plt/
#   inflating: helpers/plt/__init__.py
#  extracting: helpers/__init__.py

# %% [markdown]
# #Load  Libraries

# %%
import random
import numpy as np
import warnings
import helpers.plt, helpers.dataset
from matplotlib import pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# #HyperParameters

# %%
lr = 0.3
batch_size = 300
iterations = 40

# %% [markdown]
# #Dataset

# %%
(X_train, Y_train), (X_test, Y_test) = helpers.dataset.get_data()
# Out:
# Loading data..
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Done.

# %%
print('Shape of X_train:', X_train.shape)
print('Shape of Y_train:', Y_train.shape)
print('Shape of X_test:', X_test.shape)
print('Shape of Y_test:', Y_test.shape)
# Out:
# Shape of X_train: (12665, 28, 28)
# Shape of Y_train: (12665,)
# Shape of X_test: (2115, 28, 28)
# Shape of Y_test: (2115,)

# %%
helpers.plt.show_example(X_train[0], Y_train[0])

# %%
helpers.plt.show_example(X_train[-1], Y_train[-1])

# %% [markdown]
# #A mini Batch of Example

# %%
X_batch, Y_batch = helpers.dataset.get_random_batch(X_train, Y_train, 1)
print('X_batch shape:', X_batch.shape)
helpers.plt.show_example(X_batch[0], Y_batch[0])
# Out:
# X_batch shape: (1, 784)

# %%
X_batch, Y_batch = helpers.dataset.get_random_batch(X_test, Y_test, 1)
helpers.plt.show_example(X_batch[0], Y_batch[0])

# %%
X_batch, Y_batch = helpers.dataset.get_random_batch(X_train, Y_train, 10)
helpers.plt.show_ten_examples(X_batch, Y_batch, Y_batch)

# %% [markdown]
# #Create Model

# %%
class LogisticModel:
    def __init__(self, num_features):
        self.W = np.reshape(np.random.randn((num_features)), (num_features, 1))
        self.b = np.zeros((1, 1))
        self.num_features = num_features
        self.losses = []
        self.accuracies = []
        
    def summary(self):
        print('=================================')
        print('Number of features:', self.num_features)
        print('Shape of weights:', self.W.shape)
        print('Shape of biases:', self.b.shape)
        print('=================================')
        
model = LogisticModel(num_features=784)
model.summary()
# Out:
# =================================
# Number of features: 784
# Shape of weights: (784, 1)
# Shape of biases: (1, 1)
# =================================

# %% [markdown]
# #Forward Propagation

# %%
class LogisticModel(LogisticModel):
    def _forward_pass(self, X, Y=None):
        batch_size = X.shape[0]
        Z = np.dot(X, self.W) + self.b
        A = 1. / (1. + np.exp(-Z))
        loss = float(1e5)
        if Y is not None:
            loss = -1 * np.sum(np.dot(np.transpose(Y), np.log(A)) + \
                           np.matmul(np.transpose(1-Y), np.log(1-A)))
            loss /= batch_size
        return A, loss

# %% [markdown]
# #Backward Propogation

# %%
class LogisticModel(LogisticModel):
    def _backward_pass(self, A, X, Y):
        batch_size = X.shape[0]
        dZ = A - Y
        dW = np.dot(np.transpose(X), dZ)/batch_size
        db = np.sum(dZ)/batch_size
        return dW, db

# %% [markdown]
# #Update Parameters

# %%
class LogisticModel(LogisticModel):
    def _update_params(self, dW, db, lr):
        self.W -= lr * dW
        self.b -= lr * db

# %% [markdown]
# #Check Model Performance

# %%
class LogisticModel(LogisticModel):
    def predict(self, X, Y=None):
        A, loss = self._forward_pass(X, Y)
        Y_hat = A > 0.5
        return np.squeeze(Y_hat), loss
    
    def evaluate(self, X, Y):
        Y_hat, loss = self.predict(X, Y)
        accuracy = np.sum(Y_hat == np.squeeze(Y)) / X.shape[0]
        return accuracy, loss

# %%
model = LogisticModel(num_features=784)

model.summary()
X, Y = helpers.dataset.get_random_batch(X_test, Y_test, batch_size)
acc, loss = model.evaluate(X, Y)
print('Untrained model accuracy: {}, loss:{}'.format(acc, loss))
# Out:
# =================================
# Number of features: 784
# Shape of weights: (784, 1)
# Shape of biases: (1, 1)
# =================================
# Untrained model accuracy: 0.5766666666666667, loss:5.239577620153857

# %%
X, Y = helpers.dataset.get_random_batch(X_test, Y_test, batch_size)
preds, _ = model.predict(X)
helpers.plt.show_ten_examples(X, Y, preds)

# %% [markdown]
# #Training Loop

# %%
class LogisticModel(LogisticModel):
    def train(self, batch_size, get_batch, lr, iterations, X_train, Y_train, X_test, Y_test):

        print('Training..')
        self.accuracies = []
        self.losses = []
        
        for i in range(0, iterations):
            X, Y = get_batch(X_train, Y_train, batch_size)
            A, _ = self._forward_pass(X, Y)  
            dW, db = self._backward_pass(A, X, Y)
            self._update_params(dW, db, lr)
            
            X, Y = get_batch(X_test, Y_test, batch_size)
            val_acc, val_loss = self.evaluate(X, Y)
            self.accuracies.append(val_acc)
            self.losses.append(val_loss)
            
            print('Iter: {}, Val Acc: {:.3f}, Val Loss: {:.3f}'.format(i, val_acc, val_loss))
            
        print('Training finished.')

# %% [markdown]
# #Training Model

# %%
model = LogisticModel(num_features=784)

X, Y = helpers.dataset.get_random_batch(X_test, Y_test, batch_size)
print('Before training performance:', model.evaluate(X, Y))
model.train(
    batch_size,
    helpers.dataset.get_random_batch,
    lr,
    iterations,
    X_train, Y_train,
    X_test, Y_test
)
print('After training performance:', model.evaluate(X, Y))
# Out:
# Before training performance: (0.5733333333333334, 1.8530864455779203)
# Training..
# Iter: 0, Val Acc: 0.650, Val Loss: 1.115
# Iter: 1, Val Acc: 0.777, Val Loss: 0.690
# Iter: 2, Val Acc: 0.817, Val Loss: 0.597
# Iter: 3, Val Acc: 0.800, Val Loss: 0.619
# Iter: 4, Val Acc: 0.880, Val Loss: 0.442
# Iter: 5, Val Acc: 0.863, Val Loss: 0.459
# Iter: 6, Val Acc: 0.933, Val Loss: 0.261
# Iter: 7, Val Acc: 0.940, Val Loss: 0.206
# Iter: 8, Val Acc: 0.923, Val Loss: 0.296
# Iter: 9, Val Acc: 0.930, Val Loss: 0.318
# Iter: 10, Val Acc: 0.967, Val Loss: 0.114
# Iter: 11, Val Acc: 0.953, Val Loss: 0.117
# Iter: 12, Val Acc: 0.963, Val Loss: 0.228
# Iter: 13, Val Acc: 0.957, Val Loss: 0.180
# Iter: 14, Val Acc: 0.957, Val Loss: 0.207
# Iter: 15, Val Acc: 0.957, Val Loss: 0.160
# Iter: 16, Val Acc: 0.977, Val Loss: 0.089
# Iter: 17, Val Acc: 0.957, Val Loss: 0.119
# Iter: 18, Val Acc: 0.953, Val Loss: 0.206
# Iter: 19, Val Acc: 0.943, Val Loss: 0.174
# Iter: 20, Val Acc: 0.960, Val Loss: 0.148
# Iter: 21, Val Acc: 0.967, Val Loss: 0.127
# Iter: 22, Val Acc: 0.950, Val Loss: 0.173
# Iter: 23, Val Acc: 0.970, Val Loss: 0.124
# Iter: 24, Val Acc: 0.980, Val Loss: 0.043
# Iter: 25, Val Acc: 0.967, Val Loss: 0.118
# Iter: 26, Val Acc: 0.963, Val Loss: 0.102
# Iter: 27, Val Acc: 0.973, Val Loss: 0.095
# Iter: 28, Val Acc: 0.980, Val Loss: 0.102
# Iter: 29, Val Acc: 0.987, Val Loss: 0.061
# Iter: 30, Val Acc: 0.983, Val Loss: 0.062
# Iter: 31, Val Acc: 0.977, Val Loss: 0.069
# Iter: 32, Val Acc: 0.980, Val Loss: 0.071
# Iter: 33, Val Acc: 0.980, Val Loss: 0.061
# Iter: 34, Val Acc: 0.980, Val Loss: 0.085
# Iter: 35, Val Acc: 0.977, Val Loss: 0.105
# Iter: 36, Val Acc: 0.973, Val Loss: 0.096
# Iter: 37, Val Acc: 0.977, Val Loss: 0.141
# Iter: 38, Val Acc: 0.990, Val Loss: 0.043
# Iter: 39, Val Acc: 0.987, Val Loss: 0.035
# Training finished.
# After training performance: (0.97, 0.14102478188180936)

# %% [markdown]
# #Display Result

# %%
helpers.plt.plot_metrics(model)

# %%
X, Y = helpers.dataset.get_random_batch(X_test, Y_test, batch_size)
preds, _ = model.predict(X)
helpers.plt.show_ten_examples(X, Y, preds)
